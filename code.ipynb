# %%
import numpy as np
import pandas as pd
import cv2
from skimage.transform import resize
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("driver_imgs_list.csv") #load the cdv file of data info
category = data.classname.unique()

# %%
dataDir = "C:/Users/HITESHWAR SINGH/Desktop/Technocolabs/Dataset/imgs/train" #add directory of your dataset
training_data = []

for cat in category:
    path = os.path.join(dataDir,cat)
    classImg = np.where(category == cat)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img),cv2.COLOR_BGR2RGB)
        resize_array = resize(img_array, (128, 64))
        training_data.append([resize_array,classImg])

print(len(training_data))
# Out:
# 22424

# %%
from skimage.feature import hog
fd,hog_image = hog(resize_array, orientations=9, pixels_per_cell=(8, 8),cells_per_block=(2, 2), visualize=True, multichannel=True)

# %%
plt.imshow(training_data[1][0])

# %%
plt.axis("off")
plt.imshow(hog_image,cmap="gray")

# %%
import keras
from imutils import paths
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img

# %%
classes = ['c0', 'c1','c2','c3','c4','c5','c6','c7','c8','c9']
Dict = {'c0' : 0, 'c1' :1, 'c2':2, 'c3':3, 'c4':4,'c5':5,'c6':6,'c7':7,'c8':8,'c9':9}
images = []
Img_labels = []
train_path='C:/Users/HITESHWAR SINGH/Desktop/Technocolabs/Dataset/imgs/train'

# %%
for label in classes:
      path = os.path.join(train_path , label)
      for img in os.listdir(path):
         img = cv2.imread(os.path.join(path,img))
         new_img = cv2.resize(img, (64, 64))
         images.append(new_img)
         Img_labels.append(Dict[label])

# %%
img=np.array(images)
labels=np.array(Img_labels)
print(img.shape)
